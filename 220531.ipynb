# %%
import pandas as pd

data = pd.Series([1, 2, 3, 4, 5], index = list('abcde'))
print(data.index)
print(data)
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = pd.Series({'a' : 1})
print(data.index)
print(data)
# Out:
# Index(['a'], dtype='object')
# a    1
# dtype: int64

# %%
data1 = pd.DataFrame([1, 2, 3, 4, 5], index = list('abcde'), columns = ['hello'])
print(data1)
# Out:
#    hello
# a      1
# b      2
# c      3
# d      4
# e      5

# %%
a = [1, 2, 3]
b = [4, 5, 6]
c = [7, 8, 9]
data = pd.DataFrame([a, b, c])
data
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# ---

# %%
a = [1, 2, 3]
b = [4, 5, 6]
c = [7, 8, 9]
data = pd.DataFrame({'A' : a, 'B' : b})
data
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
data['A']
# Out:
# 0    1
# 1    2
# 2    3
# Name: A, dtype: int64

# %%
data['X'] = [6, 5, 4]
data
# Out:
#    A  B  X
# 0  1  4  6
# 1  2  5  5
# 2  3  6  4

# %%
print(df.index)
print(df.columns)
print(df.values)
# Out:
# Index(['x', 'y', 'z'], dtype='object')
# RangeIndex(start=0, stop=2, step=1)
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
import numpy as np

df = pd.DataFrame(np.arange(1, 7).reshape(3, 2), index = list('xyz'), columns = list('ab'))
df
# Out:
#    a  b
# x  1  2
# y  3  4
# z  5  6

# %%
df.loc['x']
# Out:
# a    1
# b    2
# Name: x, dtype: int64

# %%
df['c'] = []
# Out:
# x    1
# y    3
# z    5
# Name: a, dtype: int64

# %%
df.loc['w'] = [7, 8]

# %%
df
# Out:
#    a  b
# x  1  2
# y  3  4
# z  5  6
# w  7  8

# %%
df.loc[['x', 'y']]
# Out:
#    a  b
# x  1  2
# y  3  4

# %%
df.loc['x' , 'a']
# Out:
# 1

# %%
df
# Out:
#    a  b
# x  1  2
# y  3  4
# z  5  6
# w  7  8

# %%
df['he llo'] = [4, 5, 6, 7]

# %%
df
# Out:
#    a  b  he llo
# x  1  2       4
# y  3  4       5
# z  5  6       6
# w  7  8       7

# %%
df.b
# Out:
# x    2
# y    4
# z    6
# w    8
# Name: b, dtype: int64

# %%
df[df.a > 4]
# Out:
#    a  b  he llo
# z  5  6       6
# w  7  8       7

# %%
df.sort_values(by='b', ascending = False)
# Out:
#    a  b  he llo
# w  7  8       7
# z  5  6       6
# y  3  4       5
# x  1  2       4

# %%
df
# Out:
#    a  b  he llo
# x  1  2       4
# y  3  4       5
# z  5  6       6
# w  7  8       7

# %%
df.sum(axis = 0)
# Out:
# a         16
# b         20
# he llo    22
# dtype: int64

# %%
df.sum(axis = 1)
# Out:
# x     7
# y    12
# z    17
# w    22
# dtype: int64

# %%
df['a'].sum()
# Out:
# 16

# %%
df.describe()
# Out:
#               a         b    he llo
# count  4.000000  4.000000  4.000000
# mean   4.000000  5.000000  5.500000
# std    2.581989  2.581989  1.290994
# min    1.000000  2.000000  4.000000
# 25%    2.500000  3.500000  4.750000
# 50%    4.000000  5.000000  5.500000
# 75%    5.500000  6.500000  6.250000
# max    7.000000  8.000000  7.000000

# %%
df
# Out:
#    a  b  he llo
# x  1  2       4
# y  3  4       5
# z  5  6       6
# w  7  8       7

# %%
import matplotlib.pyplot as plt

plt.bar(df.a, df.b)
plt.legend(df.columns)
plt.show()
