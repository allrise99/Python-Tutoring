# %%
tmp = input("학생들 성적?")

a = tmp.split()
d = {}
for i in a :
    if i in d :
        d[i] = d.get(i) + 1
    else :
        d[i] = 1


for i in d :
    print("%s점%d명"%(i, d[i]), end = ' ')
# Out:
# 학생들 성적?10 30 20 19
# {'10': 1, '30': 1, '20': 1, '19': 1}
# 10점1명 30점1명 20점1명 19점1명

# %%
tmp = input("학생들 성적?")

a = tmp.split()
d = {}
d1 = ()

for i in a :
    if i in d :
        d[i] = d.get(i) + 1
    else :
        d[i] = 1

for i in d :
    tmp = i, d[i]
    d.append(tmp)

for i in d :
    print("%s점%d명"%(i, d[i]), end = ' ')
# Out:
# 학생들 성적?1 2 30
# {'1': 1, '2': 1, '30': 1}
# 1점1명 2점1명 30점1명
